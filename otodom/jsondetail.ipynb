# %%
import requests
headers = { 'Accept-Language' :	'en-GB,en-US;q=0.9,en;q=0.8,pl;q=0.7',
            'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'}

# %%
url='https://www.otodom.pl/pl/oferta/3-pok-ul-sosnkowskiego-47-m2-ID4mwCa'
url='https://www.otodom.pl/pl/wyniki/sprzedaz/mieszkanie/lodzkie/lodz/lodz/lodz?distanceRadius=0&viewType=listing&limit=72&page=3'

res=requests.get(url=url,headers=headers)

# %%
res.text
# Out:
# '<!DOCTYPE html><html lang="pl"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><link rel="preload" href="https://statics.otodom.pl/fp_statics/fonts/OpenSans/Regular.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://statics.otodom.pl/fp_statics/fonts/OpenSans/SemiBold.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://statics.otodom.pl/fp_statics/fonts/OpenSans/Bold.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preconnect" href="https://statics.otodom.pl"/><link rel="icon" href="https://statics.otodom.pl/static/otodompl/naspersclassifieds-regional/verticalsre-atlas-web-otodompl/static/img/favicon.svg"/><link rel="apple-touch-icon" href="https://statics.otodom.pl/static/otodompl/naspersclassifieds-regional/verticalsre-atlas-web-otodompl/static/img/app-icon.png"/><link rel="android-touch-icon" href="https://statics.otodom.pl/static/otodompl/naspersclassifieds-regional/v
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, "html.parser")

# %%
sc=soup.select_one('#__NEXT_DATA__').text
import json
j=json.loads(sc)
json.dumps(j)
# Out:
# '{"props": {"pageProps": {"lang": "pl", "_sentryTraceData": "10d6dd8f12f341088c45f0c2fb565ed8-8e3efa2189e6ffc4-0", "_sentryBaggage": "sentry-environment=otodompl-prd,sentry-release=frontend-platform%402023-08-10_16.41-otodompl,sentry-transaction=%2Fpl%2Fwyniki%2F%5B%5B...searchingCriteria%5D%5D,sentry-public_key=a87771f160f04e019f364675c25c0588,sentry-trace_id=10d6dd8f12f341088c45f0c2fb565ed8,sentry-sample_rate=0", "experiments": {"REM-1531": null, "REMD-1201": "a", "REPM-914": null, "SEE-1658": "a", "SEE-1795": "b", "SEE-1861": null, "SEORE-343": null, "SEORE-451": "b", "SFS-306": null, "SFS-603": null, "SFS-725": null, "SMR-1927": null, "SMR-1951": null, "SMR-2359": null, "SEORE-518": "a", "SEE-1753": "b", "SEE-1754": null, "SEE-1742": null, "SEE-1832": "b", "EUADS-4564": null, "SEORE-490": "b", "SFS-599": "b"}, "pageTitle": "Mieszkania na sprzeda\\u017c: \\u0141\\u00f3d\\u017a, \\u0141\\u00f3dzkie | Otodom.pl", "pageHeading": "Mieszkania na sprzeda\\u017c: \\u0141\\u00f3d\\u017a",
# ...

# %%
j['props']['pageProps']['data']['searchAds']['items'][0]
# Out:
# {'id': 64449220,
#  'title': 'Wyposażone M2 po remoncie bl. Politechniki Łódzkie',
#  'slug': 'wyposazone-m2-po-remoncie-bl-politechniki-lodzkie-ID4mqby',
#  'estate': 'FLAT',
#  'developmentId': 0,
#  'developmentTitle': '',
#  'developmentUrl': '',
#  'transaction': 'SELL',
#  'location': {'mapDetails': {'radius': 0, '__typename': 'MapDetails'},
#   'address': {'street': {'name': 'ul. Ignacego Paderewskiego',
#     'number': '',
#     '__typename': 'Street'},
#    'city': {'name': 'Łódź', '__typename': 'City'},
#    'province': {'name': 'łódzkie', '__typename': 'Province'},
#    '__typename': 'Address'},
#   'reverseGeocoding': {'locations': [{'fullName': 'łódzkie',
#      '__typename': 'BasicLocationObject'},
#     {'fullName': 'Łódź, łódzkie', '__typename': 'BasicLocationObject'},
#     {'fullName': 'Górna, Łódź, łódzkie', '__typename': 'BasicLocationObject'},
#     {'fullName': 'Kurak, Górna, Łódź, łódzkie',
#      '__typename': 'BasicLocationObject'}],
# ...

# %%
main=j['props']['pageProps']
main['id']
main['userSessionId']
main['isBotDetected']
# gps
main['adTrackingData']
# main
main['ad']
main['ad']['target']
# Out:
# {'Area': '47',
#  'AreaRange': [],
#  'Build_year': '1967',
#  'Building_floors_num': '4',
#  'Building_material': ['breezeblock'],
#  'Building_ownership': ['limited_ownership'],
#  'Building_type': ['block'],
#  'City': 'warszawa',
#  'City_id': '26',
#  'Construction_status': ['to_renovation'],
#  'Country': 'Polska',
#  'Extras_types': ['basement', 'separate_kitchen'],
#  'Floor_no': ['floor_2'],
#  'Heating': ['urban'],
#  'Id': '64470090',
#  'MarketType': 'secondary',
#  'Media_types': ['cable-television', 'internet', 'phone'],
#  'ObidoAdvert': 'n',
#  'OfferType': 'sprzedaz',
#  'Photo': '',
#  'Price': 450000,
#  'PriceRange': ['250001-500000'],
#  'Price_per_m': 9574,
# ...

# %%
import json
p='C:/Users/krawc/OneDrive/Documents/code/pythons/data-scrap/output20230812-151156.txt'
with open(p,encoding='utf-8') as f:
    contents = f.readlines()

jsondata1=json.loads(contents[0])
jsondata2=json.loads(contents[-1])

# %%
jsondata1['props']['pageProps'].keys()
# Out:
# dict_keys(['lang', '_sentryTraceData', '_sentryBaggage', 'experiments', 'pageTitle', 'pageHeading', 'pageDescription', 'tracking', 'targeting', 'breadcrumbItems', 'data', 'mapBoundingBox', 'urlViewType', 'transaction', 'estate', 'location', 'market', 'savedSearches', 'filteringQueryParams', 'filterLocations', 'filterAttributes', 'sortingOption', 'canonicalURL', 'shouldEnableIndexingByMetaRobots', 'currentUser', 'featureFlags', 'laquesisResult', 'userSessionId', 'unconfirmedUserAuthToken', 'isBotDetected'])

# %%
jsondata2['props']['pageProps'].keys()
# Out:
# dict_keys(['lang', '_sentryTraceData', '_sentryBaggage', 'experiments', 'id', 'ad', 'relativeUrl', 'adTrackingData', 'referer', 'currentUser', 'featureFlags', 'laquesisResult', 'userSessionId', 'unconfirmedUserAuthToken', 'isBotDetected'])

# %%
body = jsondata2['props']['pageProps']
def is_oferta(body):
    if 'ad' in body.keys():
        return True
    else:
        return False
is_oferta(body)
# body['id']
info = (body['userSessionId'],body['isBotDetected'])
# gps
# body['adTrackingData']
# body
body['ad']
body['ad']['target']
# Out:
# {'Area': '54',
#  'AreaRange': [],
#  'Build_year': '1990',
#  'Building_floors_num': '4',
#  'Building_material': ['breezeblock'],
#  'Building_ownership': ['full_ownership'],
#  'Building_type': ['block'],
#  'City': 'lodz',
#  'City_id': '1004',
#  'Construction_status': ['ready_to_use'],
#  'Country': 'Polska',
#  'Equipment_types': ['fridge',
#   'furniture',
#   'oven',
#   'stove',
#   'washing_machine'],
#  'Extras_types': ['balcony'],
#  'Floor_no': ['floor_4'],
#  'Heating': ['urban'],
#  'Id': '64395472',
#  'MarketType': 'secondary',
#  'Media_types': ['cable-television', 'internet', 'phone'],
#  'ObidoAdvert': 'n',
#  'OfferType': 'sprzedaz',
#  'Photo': '',
# ...

# %%
from operator import itemgetter
x=body['ad']['target']
b = itemgetter('Province')(x)
b
# Out:
# 'lodzkie'

# %%
from ogloszenie import Ogloszenie

ad_data = Ogloszenie(**jsondata2)

# %%
body=ad_data.props['pageProps']
info = (body['userSessionId'],body['isBotDetected'])
ad = body['ad']
(ad['id'],ad['adCategory'])
ad=ad_data.props.pageProps.ad


ad.id
ad.market
ad.publicId
ad.advertType
ad.createdAt
ad.modifiedAt
ad.description
ad.exclusiveOffer
ad.externalId
ad.features
ad.title
ad.agency


ad.adCategory.name
ad.adCategory.type
ad.images[0].medium
ad.location.coordinates.latitude
ad.location.coordinates.longitude
ad.location.address.city.name
ad.location.address.district.name
ad.location.address.street.name
ad.location.address.street.number
ad.location.reverseGeocoding.locations[0].locationLevel
ad.location.reverseGeocoding.locations[0].name
ad.property.type
ad.property.rent
ad.property.costs
ad.property.condition
ad.property.ownership
ad.property.area.value
ad.owner.name
ad.owner.type
ad.owner.phones

ad.characteristics[0].key
ad.characteristics[0].value

ad.topInformation[0].label
ad.topInformation[0].values
ad.additionalInformation[0].label
ad.additionalInformation[0].values

# xad.property.properties
# xad.property.buildingProperties

ad.target.Area
ad.target.Buildingfloorsnum
ad.target.Buildingownership
ad.target.Buildingtype
ad.target.Buildyear
ad.target.Constructionstatus
ad.target.Extrastypes
ad.target.Floorno
ad.target.Heating
ad.target.MarketType
ad.target.OfferType
ad.target.Price
ad.target.ProperType
ad.target.Roomsnum
ad.target.Title
ad.target.usertype
ad.target.Windowstype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\krawc\OneDrive\Documents\code\pythons\pandas-projects\testy.ipynb Cell 26 in 5
#       <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/testy.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> ad = body['ad']
#       <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/testy.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> (ad['id'],ad['adCategory'])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/testy.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> ad=ad_data.props.pageProps.ad
#       <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/testy.ipynb#X34sZmlsZQ%3D%3D?line=7'>8</a> ad.id
# ...

# %%
ad_data=jsondata2
body=ad_data['props']['pageProps']
info = (body['userSessionId'],body['isBotDetected'])

ad = body['ad']
ad=ad_data['props']['pageProps']['ad']

def is_lift():
    try:
        return [x['values'][0].replace(':',"") for x in ad['additionalInformation'] if x['label']=='lift'][0]
    except:
        return 'N'


dict0={'id':ad['id'],
# 'market':xad['market'],
'publicId':ad['publicId'],
'advertType':ad['advertType'],
'createdAt':ad['createdAt'],
'modifiedAt':ad['modifiedAt'],
'description':ad['description'],
'exclusiveOffer':ad['exclusiveOffer'],
'externalId':ad['externalId'],
'features':','.join(ad['features']),
'title':ad['title'],
'agency':ad['agency']['name'] if ad['agency'] else '',

'adCategoryname':ad['adCategory']['name'],
'adCategorytype':ad['adCategory']['type'],
'latitude':ad['location']['coordinates']['latitude'],
'longitude':ad['location']['coordinates']['longitude'],
'cityname':ad['location']['address']['city']['name'],
'districtname':ad['location']['address']['district']['name'],
'streetname':ad['location']['address']['street']['name'] if ad['location']['address']['street'] else '',
'number':ad['location']['address']['street']['number'] if ad['location']['address']['street'] else '',
# 'propertytype':xad['property']['type'],
'rent':ad['property']['rent']['value'] if ad['property']['rent'] else '',
'costs':','.join(ad['property']['costs']),
'condition':ad['property']['condition'],
'ownership':ad['property']['ownership'],
# 'area':xad['property']['area']['value'],
'ownername':ad['owner']['name'],
# 'ownertype':xad['owner']['type'],
'phones':','.join(ad['owner']['phones']),

'images':','.join([x['medium'] for x in ad['images']]),

# [(x['locationLevel'],x['name']) for x in xad['location']['reverseGeocoding']['locations']]
# [(x['key'],','.join(x['value'])) for x in xad['characteristics']]
# [(x['label'],','.join(x['values'])) for x in xad['topInformation']]
# [(x['label'],','.join(x['values'])) for x in xad['additionalInformation']]


# xad['property']['properties']
# xad['property']['buildingProperties']

'Area':ad['target']['Area'],
'Building_floors_num':ad['target']['Building_floors_num'],
# 'Building_ownership':','.join(xad['target']['Building_ownership']),
'Building_type':','.join(ad['target']['Building_type']),
'Building_material':','.join(ad['target']['Building_material']),
'Build_year':ad['target']['Build_year'],
'Construction_status':','.join(ad['target']['Construction_status']),
'Extras_types':','.join(ad['target']['Extras_types']),
'Floor_no':','.join(ad['target']['Floor_no']),
'Heating':','.join(ad['target']['Heating']),
'MarketType':ad['target']['MarketType'],
'OfferType':ad['target']['OfferType'],
'Price':ad['target']['Price'],
'ProperType':ad['target']['ProperType'],
'Rooms_num':','.join(ad['target']['Rooms_num']),
# 'Title':xad['target']['Title'],
# 'user_type':xad['target']['user_type'],
'Windows_type':','.join(ad['target']['Windows_type']),
'Lift':is_lift()}

dict1={k:v for k,v in [(x['locationLevel'],x['name']) for x in ad['location']['reverseGeocoding']['locations']]}

# dict2={k:v for k,v in [(x['key'],x['value']) for x in xad['characteristics']]}
# dict3={k:v for k,v in [(x['label'],','.join(x['values'])) for x in xad['topInformation']]}
# dict4={k:v for k,v in [(x['label'],','.join(x['values'])) for x in xad['additionalInformation']]}

# %%
dict0.update(dict1)
# dict0.update(dict2)
# dict0.update(dict3)
# dict0.update(dict4)
dict0
# Out:
# {'id': 64395472,
#  'publicId': '4mccE',
#  'advertType': 'AGENCY',
#  'createdAt': '2023-07-06T19:44:55+02:00',
#  'modifiedAt': '2023-08-12T12:33:45+02:00',
# ...

# %%
df=pd.DataFrame(dict0)
pd.set_option('display.max_rows',None)
df.transpose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\krawc\OneDrive\Documents\code\pythons\pandas-projects\testy.ipynb Cell 29 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/testy.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> df=pd.DataFrame(dict0)
#       <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/testy.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> pd.set_option('display.max_rows',None)
#       <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/testy.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> df.transpose()
#
# NameError: name 'pd' is not defined

# %%
def extract_oferta_from_json(jsondata):

    def is_oferta(jsondata):
        body = jsondata['props']['pageProps']
        if 'ad' in body.keys():
            return True
        else:
            return False

    def is_lift():
        try:
            return [x['values'][0].replace(':',"") for x in ad['additionalInformation'] if x['label']=='lift'][0]
        except:
            return 'n'
        
    chk_is_oferta = is_oferta(jsondata)

    body=jsondata['props']['pageProps']

    info = {'userSessionId':body['userSessionId'],'isBotDetected':body['isBotDetected']}

    if not chk_is_oferta:
        return {'is_oferta':chk_is_oferta,'info':info,'data':None}

    ad = body['ad']

    main={'id':ad['id'],
    'publicId':ad['publicId'],
    'advertType':ad['advertType'],
    'createdAt':ad['createdAt'],
    'modifiedAt':ad['modifiedAt'],
    'description':ad['description'],
    'exclusiveOffer':ad['exclusiveOffer'],
    'externalId':ad['externalId'],
    'features':','.join(ad['features']),
    'title':ad['title'],
    'agency':ad['agency']['name'] if ad['agency'] else '',
    'adCategoryname':ad['adCategory']['name'],
    'adCategorytype':ad['adCategory']['type'],
    'latitude':ad['location']['coordinates']['latitude'],
    'longitude':ad['location']['coordinates']['longitude'],
    'cityname':ad['location']['address']['city']['name'],
    'districtname':ad['location']['address']['district']['name'],
    'streetname':ad['location']['address']['street']['name'] if ad['location']['address']['street'] else '',
    'number':ad['location']['address']['street']['number'] if ad['location']['address']['street'] else '',
    'rent':ad['property']['rent']['value'] if ad['property']['rent'] else '',
    'costs':','.join(ad['property']['costs']),
    'condition':ad['property']['condition'],
    'ownership':ad['property']['ownership'],
    'ownername':ad['owner']['name'],
    'phones':','.join(ad['owner']['phones']),
    'images':','.join([x['medium'] for x in ad['images']]),
    'Area':ad['target']['Area'],
    'Building_floors_num':ad['target']['Building_floors_num'] if ad['target'].get('Building_floors_num') else '',
    'Building_type':','.join(ad['target']['Building_type']) if ad['target'].get('Building_type') else '',
    'Building_material':','.join(ad['target']['Building_material']) if ad['target'].get('Building_material') else '',
    'Build_year':ad['target']['Build_year'] if ad['target'].get('Build_year') else '',
    'Construction_status':','.join(ad['target']['Construction_status']),
    'Extras_types':','.join(ad['target']['Extras_types']),
    'Floor_no':','.join(ad['target']['Floor_no']),
    'Heating':','.join(ad['target']['Heating']) if ad['target'].get('Heating') else '',
    'MarketType':ad['target']['MarketType'],
    'OfferType':ad['target']['OfferType'],
    'Price':ad['target']['Price'],
    'ProperType':ad['target']['ProperType'],
    'Rooms_num':','.join(ad['target']['Rooms_num']),
    'Windows_type':','.join(ad['target']['Windows_type']) if ad['target'].get('Windows_type') else '',
    'Lift':is_lift()}

    geo={k:v for k,v in [(x['locationLevel'],x['name']) for x in ad['location']['reverseGeocoding']['locations']]}
    main.update(geo)

    return {'is_oferta':chk_is_oferta,'info':info,'data':main}

# %%
for ofer in contents:
    jsondata=json.loads(ofer)
    extract_oferta_from_json(jsondata)

# %%
# Out:
# {'locations': [{'id': 'lodzkie',
#    'locationLevel': 'voivodeship',
#    'name': 'łódzkie',
#    'fullName': 'łódzkie',
#    'fullNameItems': ['łódzkie'],
#    'parentIds': [],
#    '__typename': 'BasicLocationObject'},
#   {'id': 'lodzkie/lodz/lodz/lodz',
#    'locationLevel': 'city_or_village',
#    'name': 'Łódź',
#    'fullName': 'Łódź, łódzkie',
#    'fullNameItems': ['Łódź', 'łódzkie'],
#    'parentIds': ['lodzkie', 'lodzkie/lodz', 'lodzkie/lodz/lodz'],
#    '__typename': 'BasicLocationObject'},
#   {'id': 'lodzkie/lodz/lodz/lodz/baluty',
#    'locationLevel': 'district',
#    'name': 'Bałuty',
#    'fullName': 'Bałuty, Łódź, łódzkie',
#    'fullNameItems': ['Bałuty', 'Łódź', 'łódzkie'],
#    'parentIds': ['lodzkie',
#     'lodzkie/lodz',
#     'lodzkie/lodz/lodz',
#     'lodzkie/lodz/lodz/lodz'],
#    '__typename': 'BasicLocationObject'},
#   {'id': 'lodzkie/lodz/lodz/lodz/baluty/julianow',
#    'locationLevel': 'residential',
#    'name': 'Julianów',
# ...
