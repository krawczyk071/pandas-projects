# %%
import pandas as pd
import numpy as np 
df = pd.read_csv(r'C:\Users\krawc\OneDrive\Documents\code\pythons\data-scrap\output20230812-202601.csv',delimiter=';')

# %%
df.append(df2)
# Out:
# C:\Users\krawc\AppData\Local\Temp\ipykernel_420\2094904254.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df2)
#           id publicId      advertType                  createdAt  \
# 0   64009518    4kzNA         PRIVATE  2023-03-07T09:39:14+01:00
# 1   64496155    4mCoz          AGENCY  2023-08-08T17:05:39+02:00
# 2   64445703    4mpgP  DEVELOPER_UNIT  2023-07-24T08:44:33+02:00
# 3   64435440    4mmBi          AGENCY  2023-07-20T09:08:02+02:00
# 4   64469100    4mwmc         PRIVATE  2023-07-31T16:47:39+02:00
# ..       ...      ...             ...                        ...
# 70  64432145    4mlK9          AGENCY  2023-07-19T12:23:23+02:00
# 71  64398741    4md3n          AGENCY  2023-07-07T17:19:55+02:00
# 72  64446768    4mpy0  DEVELOPER_UNIT  2023-07-24T12:28:13+02:00
# 73  64495350    4mCbA         PRIVATE  2023-08-08T15:09:00+02:00
# ...

# %%
df2 = pd.read_csv(r'C:\Users\krawc\OneDrive\Documents\code\pythons\data-scrap\output20230812-211824.csv',delimiter=';')

# %%
df3 = pd.read_csv(r'C:\Users\krawc\OneDrive\Documents\code\pythons\data-scrap\output20230812-212620.csv',delimiter=';')

# %%
df4 = pd.read_csv(r'C:\Users\krawc\OneDrive\Documents\code\pythons\data-scrap\output20230812-230412.csv',delimiter=';')

# %%
df5 = pd.read_csv(r'C:\Users\krawc\OneDrive\Documents\code\pythons\data-scrap\output20230813-004009.csv',delimiter=';')

# %%
df6 = pd.read_csv(r'C:\Users\krawc\OneDrive\Documents\code\pythons\data-scrap\output20230813-092446.csv',delimiter=';')

# %%
df7 = pd.read_csv(r'C:\Users\krawc\OneDrive\Documents\code\pythons\data-scrap\output20230813-111354.csv',delimiter=';')

# %%
df8 = pd.read_csv(r'C:\Users\krawc\OneDrive\Documents\code\pythons\data-scrap\output20230813-215105.csv',delimiter=';')

# %%
all=df.append(df2).append(df3).append(df4).append(df5).append(df6).append(df7).append(df8)
# Out:
# C:\Users\krawc\AppData\Local\Temp\ipykernel_420\1541254228.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all=df.append(df2).append(df3).append(df4).append(df5).append(df6).append(df7).append(df8)
# C:\Users\krawc\AppData\Local\Temp\ipykernel_420\1541254228.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all=df.append(df2).append(df3).append(df4).append(df5).append(df6).append(df7).append(df8)
# C:\Users\krawc\AppData\Local\Temp\ipykernel_420\1541254228.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all=df.append(df2).append(df3).append(df4).append(df5).append(df6).append(df7).append(df8)
# ...

# %%
#'modifiedAt'	
all.drop_duplicates('publicId',inplace=True)
all.sort_values('id',inplace=True)

# %%
all.to_csv('wawa_all.csv',sep=';',index=False)
output20230813-215105.csv
