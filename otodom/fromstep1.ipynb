# %%
import pandas as pd
from utils import after_dot,history_fill,add_empty_col,Geolocator
g=Geolocator()

df = pd.read_csv('./out2.csv',delimiter=';',encoding='utf-8',encoding_errors='replace')

# %%
df
# Out:
#              date                                               link  \
# 0      2023-08-08  http://www.otodom.pl/pl/oferta/dwa-pokoje-na-n...
# 1      2023-08-08  http://www.otodom.pl/pl/oferta/mieszkanie-wars...
# 2      2023-08-08  http://www.otodom.pl/pl/oferta/seg-srodkowy-st...
# 3      2023-08-08  http://www.otodom.pl/pl/oferta/doskonala-lokal...
# 4      2023-08-08  http://www.otodom.pl/pl/oferta/mieszkanie-na-o...
# ...           ...                                                ...
# 11324  2023-08-08  http://www.otodom.pl/pl/oferta/pola-mokotowski...
# 11325  2023-08-08  http://www.otodom.pl/pl/oferta/mieszkanie-113-...
# 11326  2023-08-08  http://www.otodom.pl/pl/oferta/mieszkanie-200-...
# 11327  2023-08-08  http://www.otodom.pl/pl/oferta/3-pokoje-54-m2-...
# 11328  2023-08-08  http://www.otodom.pl/pl/oferta/sprzedam-mieszk...
#
#                                                     name  \
# 0                              Dwa pokoje na Nowolipkach
# ...

# %%
g.geolocate_empty(df,'where')
# Out:
# 9 - records needs geocoding

# %%
# Export
df.to_csv('./out3.csv',sep=';',index=False)

# %%
df
# Out:
#              date                                               link  \
# 0      2023-08-08  http://www.otodom.pl/pl/oferta/dwa-pokoje-na-n...
# 1      2023-08-08  http://www.otodom.pl/pl/oferta/mieszkanie-wars...
# 2      2023-08-08  http://www.otodom.pl/pl/oferta/seg-srodkowy-st...
# 3      2023-08-08  http://www.otodom.pl/pl/oferta/doskonala-lokal...
# 4      2023-08-08  http://www.otodom.pl/pl/oferta/mieszkanie-na-o...
# ...           ...                                                ...
# 11324  2023-08-08  http://www.otodom.pl/pl/oferta/pola-mokotowski...
# 11325  2023-08-08  http://www.otodom.pl/pl/oferta/mieszkanie-113-...
# 11326  2023-08-08  http://www.otodom.pl/pl/oferta/mieszkanie-200-...
# 11327  2023-08-08  http://www.otodom.pl/pl/oferta/3-pokoje-54-m2-...
# 11328  2023-08-08  http://www.otodom.pl/pl/oferta/sprzedam-mieszk...
#
#                                                     name  \
# 0                              Dwa pokoje na Nowolipkach
# ...
