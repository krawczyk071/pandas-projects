# %%
import requests
headers = { 'Accept-Language' :	'en-GB,en-US;q=0.9,en;q=0.8,pl;q=0.7',
            'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'}

# %%
url='https://www.otodom.pl/pl/wyniki/sprzedaz/mieszkanie/lodzkie/lodz/lodz/lodz?distanceRadius=0&viewType=listing&limit=72&page=3'
url='https://www.otodom.pl/pl/wyniki/wynajem/mieszkanie/lodzkie/lodz/lodz/lodz?distanceRadius=0&viewType=listing&limit=72&page=3'
res=requests.get(url=url,headers=headers)


from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, "html.parser")
nextdata=soup.select_one('#__NEXT_DATA__').text
import json
jsondata=json.loads(nextdata)

# %%
body = jsondata['props']['pageProps']

# %%
body.keys()
# Out:
# dict_keys(['lang', '_sentryTraceData', '_sentryBaggage', 'experiments', 'pageTitle', 'pageHeading', 'pageDescription', 'tracking', 'targeting', 'breadcrumbItems', 'data', 'mapBoundingBox', 'urlViewType', 'transaction', 'estate', 'location', 'market', 'savedSearches', 'filteringQueryParams', 'filterLocations', 'filterAttributes', 'sortingOption', 'canonicalURL', 'shouldEnableIndexingByMetaRobots', 'currentUser', 'featureFlags', 'laquesisResult', 'userSessionId', 'unconfirmedUserAuthToken', 'isBotDetected'])

# %%
json.dumps(jsondata)
# Out:
# '{"props": {"pageProps": {"lang": "pl", "_sentryTraceData": "8e4592d8132d4b35ba53e9c068508d89-b250a1979928754f-0", "_sentryBaggage": "sentry-environment=otodompl-prd,sentry-release=frontend-platform%402023-08-14_10.43-otodompl,sentry-transaction=%2Fpl%2Fwyniki%2F%5B%5B...searchingCriteria%5D%5D,sentry-public_key=a87771f160f04e019f364675c25c0588,sentry-trace_id=8e4592d8132d4b35ba53e9c068508d89,sentry-sample_rate=0", "experiments": {"REM-1531": null, "REMD-1201": null, "REPM-914": null, "SEE-1658": "b", "SEE-1795": "a", "SEE-1861": null, "SEORE-343": null, "SEORE-451": "b", "SFS-306": null, "SFS-603": null, "SFS-725": null, "SMR-1927": null, "SMR-1951": null, "SMR-2359": null, "SEORE-518": "a", "SEE-1753": "b", "SEE-1754": null, "SEE-1742": null, "SEE-1832": "b", "EUADS-4564": null, "SEORE-490": "b", "SFS-599": "a"}, "pageTitle": "Mieszkania na wynajem: \\u0141\\u00f3d\\u017a, \\u0141\\u00f3dzkie | Otodom.pl", "pageHeading": "Mieszkania na wynajem: \\u0141\\u00f3d\\u017a", "pageDescription": "Zobacz 1067 og\\u0142osze\\u0144 o mieszkania na wynajem w \\u0141\\u00f3d\\u017a, \\u0142\\u00f3dzkie. Sprawd\\u017a na Otodom.pl!", "tracking": {"listing": {"cat_l1_id": 102, "cat_l1_name": "flat", "business": "rent", "page_nb": 3, "page_count": 15, "result_count": 1067, "results_per_page": 72, "listing_format": "list", "ad_impressions": [64507902, 64507897, 64507893, 64507875, 64507857, 64507849, 64507828, 64450836, 62840768, 64429842, 64465862, 64250386, 64462532, 64507050, 59893373, 64506870, 64506862, 64506861, 64472809, 64461805, 64506763, 64443169, 60042590, 64428539, 64506392, 64506086, 62057082, 64334784, 64505900, 64505739, 64505656, 64345565, 47965092, 62117083, 62038571, 60876736, 64262287, 64486071, 64445784, 64442740, 62990777, 64470482, 63989629, 64445480, 63245592, 64504936, 63465182, 64504913, 64485929, 64445324, 62645616, 64445301, 63642685, 64504587, 64469786, 64504512, 64465042, 64504476, 62095965, 64504383, 64469510, 64504300, 64441894, 64469392, 64377124, 64441797, 64032628, 64504026, 64458695, 64503984, 64503889, 64503854, 58748852, 64505739, 64499709], "selected_locations_id": ["city:lodzkie/lodz/lodz/lodz"], "market": "primary or secondary", "order_by": "default_desc", "re_seller_type": "all"}, "search": {"ad_id_selected": null, "ad_inserted_since": null, "building_material": null, "building_type": null, "bungalow": null, "commodity": null, "condition": null, "distance_filt": 0, "divisioning_type": null, "exclusive": null, "floor": null, "free_from": null, "from_construction_year": null, "from_height": null, "from_land_area": null, "from_nb_floors": null, "from_price_m2": null, "from_price": null, "from_surface": null, "heating": null, "infrastructure": null, "keyword": null, "main": null, "media": null, "nb_people": null, "nb_rooms": null, "non_smoker": null, "only_open_day": null, "only_private": null, "only_recreation": null, "plot_type": null, "re_seller_type": "all", "remote_services": null, "rent_to_students": null, "roof_type": null, "security": null, "selected_locations_id": [], "structure": null, "surroundings": null, "to_construction_year": null, "to_height": null, "to_land_area": null, "to_nb_floors": null, "to_price_m2": null, "to_price": null, "to_surface": null, "use_types": null, "vicinity_types": null, "wc_count": null, "with_3d_view": null, "with_ac": null, "with_balcony": null, "with_cellar": null, "with_garage": null, "with_garden": null, "with_lift": null, "with_maisonette": null, "with_movie": null, "with_parking": null, "with_photo": null, "with_separate_kitchen": null, "with_storage_room": null, "with_terrace": null, "cat_l1_name": "flat", "cat_l1_id": 102, "business": "rent", "market": "primary or secondary"}}, "targeting": {"env": "production", "Country": "Polska", "ProperType": "mieszkanie", "OfferType": "wynajem", "City": [], "Dist": "0", "Market": "ALL", "Region": [], "RegularUser": "n", "Subregion": []}, "breadcrumbItems": [{"label": "Otodom", "url": "/"}, {"label": "Mieszkania na wynaj ...

# %%
ads = body['data']['searchAds']
ads['pagination'].keys()
# Out:
# dict_keys(['totalResults', 'itemsPerPage', 'page', 'totalPages', '__typename'])

# %%
[*ads['items'][0].keys()][20:]
# Out:
# ['areaInSquareMeters',
#  'terrainAreaInSquareMeters',
#  'roomsNumber',
#  'hidePrice',
#  'investmentState',
#  'investmentUnitsAreaInSquareMeters',
#  'peoplePerRoom',
#  'dateCreated',
#  'dateCreatedFirst',
#  'investmentUnitsNumber',
#  'investmentUnitsRoomsNumber',
#  'investmentEstimatedDelivery',
#  'pushedUpAt',
#  'seo',
#  'specialOffer',
#  '__typename',
#  'totalPossibleImages']

# %%
 'id',
 'title',
'slug',
 'estate',
 'developmentId',
 'transaction',
 'location',
address
reverseGeocoding
 'isPrivateOwner',
 'agency'['name'],
 'totalPrice'['value'],
 'rentPrice'['value'],
 'areaInSquareMeters',
 'roomsNumber',
 'peoplePerRoom',
 'dateCreated',
 'dateCreatedFirst',
 'pushedUpAt',
# Out:
# <>:11: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <>:12: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <>:13: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <>:11: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <>:12: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <>:13: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\krawc\OneDrive\Documents\code\pythons\pandas-projects\otodom\jsonindex.ipynb Cell 8 in 8
#       <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/otodom/jsonindex.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> 'transaction',
#       <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/otodom/jsonindex.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> 'location',
# ----> <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/otodom/jsonindex.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> address
#       <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/otodom/jsonindex.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> reverseGeocoding
#      <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/pandas-projects/otodom/jsonindex.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> 'isPrivateOwner',
#
# NameError: name 'address' is not defined

# %%
item=ads['items'][0]
main={ 'id':item['id'],
 'title':item['title'],
 'slug':item['slug'],
 'estate':item['estate'],
 'developmentId':item['developmentId'],
 'transaction':item['transaction'],
 'isPrivateOwner':item['isPrivateOwner'],
 'agency':item['agency']['name'] if item.get('agency') else '',
 'totalPrice':item['totalPrice']['value'],
 'rentPrice':item['rentPrice']['value'] if item.get('rentPrice') else '',
 'areaInSquareMeters':item['areaInSquareMeters'],
 'roomsNumber':item['roomsNumber'],
 'peoplePerRoom':item['peoplePerRoom'],
 'dateCreated':item['dateCreated'],
 'dateCreatedFirst':item['dateCreatedFirst'],
 'pushedUpAt':item['pushedUpAt'], 
    
 'latitude':item['location']['coordinates'].get('latitude') if item['location'].get('coordinates') else '',
 'longitude':item['location']['coordinates'].get('longitude') if item['location'].get('coordinates') else '',
 'cityname':item['location']['address']['city']['name'] if item['location']['address']['city'] else '',
 'districtname':item['location']['address']['district']['name'] if item['location']['address'].get('district') else '',
 'streetname':item['location']['address']['street']['name'] if item['location']['address']['street'] else '',
 'number':item['location']['address']['street']['number'] if item['location']['address']['street'] else '',
 }
 
#  if item['location'].get('reverseGeocoding'):
#      geo={k:v for k,v in [(x['locationLevel'],x['name']) for x in item['location']['reverseGeocoding']['locations']]}
#      main.update(geo)

# %%
def extract_ads_from_json(jsondata):

    body=jsondata['props']['pageProps']
    ads = body['data']['searchAds']

    info = {'userSessionId':body['userSessionId'],'isBotDetected':body['isBotDetected']}
    pagination={
'totalResults':ads['pagination']['totalResults'], 
'itemsPerPage':ads['pagination']['itemsPerPage'], 
'page':ads['pagination']['page'], 
'totalPages':ads['pagination']['totalPages']}

    data_list =[]
    for item in ads['items']:

        main={'id':item['id'],
            'title':item['title'],
            'slug':item['slug'],
            'estate':item['estate'],
            'developmentId':item['developmentId'],
            'transaction':item['transaction'],
            'isPrivateOwner':item['isPrivateOwner'],
            'agency':item['agency']['name'] if item.get('agency') else '',
            'totalPrice':item['totalPrice']['value'] if item.get('totalPrice') else '',
            'rentPrice':item['rentPrice']['value'] if item.get('rentPrice') else '',
            'areaInSquareMeters':item['areaInSquareMeters'],
            'roomsNumber':item['roomsNumber'],
            'peoplePerRoom':item['peoplePerRoom'],
            'dateCreated':item['dateCreated'],
            'dateCreatedFirst':item['dateCreatedFirst'],
            'pushedUpAt':item['pushedUpAt'], 

            'latitude':item['location']['coordinates'].get('latitude') if item['location'].get('coordinates') else '',
            'longitude':item['location']['coordinates'].get('longitude') if item['location'].get('coordinates') else '',
            'cityname':item['location']['address']['city']['name'] if item['location']['address']['city'] else '',
            'districtname':item['location']['address']['district']['name'] if item['location']['address'].get('district') else '',
            'streetname':item['location']['address']['street']['name'] if item['location']['address']['street'] else '',
            'number':item['location']['address']['street']['number'] if item['location']['address']['street'] else '',
            'geo':item['location']['reverseGeocoding']['locations'][-1]['fullName'] if item['location']['reverseGeocoding'].get('locations') else '',
        }
        
        data_list.append(main)

    return {'pagination':pagination,'info':info,'data_list':data_list}

# %%
extract_ads_from_json(jsondata)
# Out:
# {'pagination': {'totalResults': 1067,
#   'itemsPerPage': 72,
#   'page': 3,
#   'totalPages': 15},
#  'info': {'userSessionId': 'ccf5e21d-af9c-4ad8-bcde-513d5d37de09',
#   'isBotDetected': False},
#  'data_list': [{'id': 64507902,
#    'title': 'nowe –Tuwima 64A/11 – w klimacie loftowym',
#    'slug': 'nowe-tuwima-64a-11-w-klimacie-loftowym-ID4mFs2',
#    'estate': 'FLAT',
#    'developmentId': 63786368,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Vantage Rent',
#    'totalPrice': 1954,
#    'rentPrice': 259,
#    'areaInSquareMeters': 30.43,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 17:46:10',
#    'dateCreatedFirst': '2023-08-11 17:45:59',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Juliana Tuwima',
#    'number': '',
#    'geo': 'Fabryczna Widzew, Widzew, Łódź, łódzkie'},
#   {'id': 64507897,
#    'title': 'nowe – Tuwima 64/119 - bez pośredników',
#    'slug': 'nowe-tuwima-64-119-bez-posrednikow-ID4mFrX',
#    'estate': 'FLAT',
#    'developmentId': 63786368,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Vantage Rent',
#    'totalPrice': 2266,
#    'rentPrice': 293,
#    'areaInSquareMeters': 30.98,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 17:44:59',
#    'dateCreatedFirst': '2023-08-11 17:44:52',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Juliana Tuwima',
#    'number': '',
#    'geo': 'Fabryczna Widzew, Widzew, Łódź, łódzkie'},
#   {'id': 64507893,
#    'title': 'nowe – Tuwima 64A/21 - bez pośredników',
#    'slug': 'nowe-tuwima-64a-21-bez-posrednikow-ID4mFrT',
#    'estate': 'FLAT',
#    'developmentId': 63786368,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Vantage Rent',
#    'totalPrice': 3421,
#    'rentPrice': 668,
#    'areaInSquareMeters': 78.61,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 17:44:14',
#    'dateCreatedFirst': '2023-08-11 17:44:02',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Juliana Tuwima',
#    'number': '',
#    'geo': 'Fabryczna Widzew, Widzew, Łódź, łódzkie'},
#   {'id': 64507875,
#    'title': 'nowe – Tuwima 64A/6-wynajmij na firmę i odlicz VAT',
#    'slug': 'nowe-tuwima-64a-6-wynajmij-na-firme-i-odlicz-vat-ID4mFrB',
#    'estate': 'FLAT',
#    'developmentId': 63786368,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Vantage Rent',
#    'totalPrice': 1860,
#    'rentPrice': 222,
#    'areaInSquareMeters': 26.06,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 17:43:02',
#    'dateCreatedFirst': '2023-08-11 17:42:50',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Juliana Tuwima',
#    'number': '',
#    'geo': 'Fabryczna Widzew, Widzew, Łódź, łódzkie'},
#   {'id': 64507857,
#    'title': 'nowe – Tuwima 64A/99 - bez pośredników',
#    'slug': 'nowe-tuwima-64a-99-bez-posrednikow-ID4mFrj',
#    'estate': 'FLAT',
#    'developmentId': 63786368,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Vantage Rent',
#    'totalPrice': 2418,
#    'rentPrice': 391,
#    'areaInSquareMeters': 45.95,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 17:42:09',
#    'dateCreatedFirst': '2023-08-11 17:41:55',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Juliana Tuwima',
#    'number': '',
#    'geo': 'Fabryczna Widzew, Widzew, Łódź, łódzkie'},
#   {'id': 64507849,
#    'title': 'nowe – Tuwima 64A/39 - bez pośredników',
#    'slug': 'nowe-tuwima-64a-39-bez-posrednikow-ID4mFrb',
#    'estate': 'FLAT',
#    'developmentId': 63786368,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Vantage Rent',
#    'totalPrice': 2621,
#    'rentPrice': 479,
#    'areaInSquareMeters': 56.33,
#    'roomsNumber': 'THREE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 17:40:34',
#    'dateCreatedFirst': '2023-08-11 17:40:23',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Juliana Tuwima',
#    'number': '',
#    'geo': 'Fabryczna Widzew, Widzew, Łódź, łódzkie'},
#   {'id': 64507828,
#    'title': '2 pokoje na wynajem ul. Sacharowa',
#    'slug': '2-pokoje-na-wynajem-ul-sacharowa-ID4mFqQ',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': '55 Nieruchomości',
#    'totalPrice': 1700,
#    'rentPrice': 600,
#    'areaInSquareMeters': 48,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 17:35:25',
#    'dateCreatedFirst': '2023-08-11 17:35:15',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Widzew Wschód, Widzew, Łódź, łódzkie'},
#   {'id': 64450836,
#    'title': 'Łódź - Śródmieście | 2 pokojowe | w samym centrum',
#    'slug': 'lodz-srodmiescie-2-pokojowe-w-samym-centrum-ID4mqBC',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Flat4Rent',
#    'totalPrice': 2300,
#    'rentPrice': 900,
#    'areaInSquareMeters': 47.2,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 17:34:06',
#    'dateCreatedFirst': '2023-07-25 13:15:29',
#    'pushedUpAt': '2023-08-11T17:34:06+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Piotrkowska',
#    'number': '',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'},
#   {'id': 62840768,
#    'title': 'Dwupokojowe mieszkanie na wynajem, Tymienieckiego',
#    'slug': 'dwupokojowe-mieszkanie-na-wynajem-tymienieckiego-ID4fFKM',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 3300,
#    'rentPrice': 400,
#    'areaInSquareMeters': 41,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 17:11:32',
#    'dateCreatedFirst': '2022-03-04 10:58:25',
#    'pushedUpAt': '2023-08-11T17:11:33+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Księży Młyn, Widzew, Łódź, łódzkie'},
#   {'id': 64429842,
#    'title': 'Senatorska, 2 pokoje do pierwszego zamieszkania!',
#    'slug': 'senatorska-2-pokoje-do-pierwszego-zamieszkania-ID4ml90',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2250,
#    'rentPrice': 450,
#    'areaInSquareMeters': 41.5,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 17:06:38',
#    'dateCreatedFirst': '2023-07-18 17:04:26',
#    'pushedUpAt': '2023-08-11T17:06:38+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Senatorska',
#    'number': '',
#    'geo': 'Górniak, Górna, Łódź, łódzkie'},
#   {'id': 64465862,
#    'title': 'WYNAJMĘ M2 RADOGOSZCZ39m2OSIEDLE ZAMKNIĘTE i garaż',
#    'slug': 'wynajme-m2-radogoszcz39m2osiedle-zamkniete-i-garaz-ID4muwY',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1800,
#    'rentPrice': 500,
#    'areaInSquareMeters': 39,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 15:30:04',
#    'dateCreatedFirst': '2023-07-30 15:25:22',
#    'pushedUpAt': '2023-08-11T15:30:04+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Motylowa',
#    'number': '',
#    'geo': 'Radogoszcz, Bałuty, Łódź, łódzkie'},
#   {'id': 64250386,
#    'title': 'Nowoczesny apartament 3 pok. z garażem w Centrum',
#    'slug': 'nowoczesny-apartament-3-pok-z-garazem-w-centrum-ID4lAsy',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Agencja Nieruchomości CITY POINT',
#    'totalPrice': 3150,
#    'rentPrice': 690,
#    'areaInSquareMeters': 63,
#    'roomsNumber': 'THREE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 15:19:18',
#    'dateCreatedFirst': '2023-05-23 08:55:21',
#    'pushedUpAt': '2023-08-11T15:19:18+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Łąkowa',
#    'number': '',
#    'geo': 'Stare Polesie, Polesie, Łódź, łódzkie'},
#   {'id': 64462532,
#    'title': 'Mieszkanie dwupokojowe przy Rondzie Solidarności',
#    'slug': 'mieszkanie-dwupokojowe-przy-rondzie-solidarnosci-ID4mtEg',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Agencja Nieruchomości CITY POINT',
#    'totalPrice': 2200,
#    'rentPrice': 700,
#    'areaInSquareMeters': 50,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 15:18:01',
#    'dateCreatedFirst': '2023-07-28 14:55:17',
#    'pushedUpAt': '2023-08-11T15:18:01+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Źródłowa',
#    'number': '',
#    'geo': 'Fabryczna, Śródmieście, Łódź, łódzkie'},
#   {'id': 64507050,
#    'title': 'Dwa pokoje na Teofilowie przy Żabieńcu.',
#    'slug': 'dwa-pokoje-na-teofilowie-przy-zabiencu-ID4mFei',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Sim Property',
#    'totalPrice': 1600,
#    'rentPrice': '',
#    'areaInSquareMeters': 37,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 15:10:33',
#    'dateCreatedFirst': '2023-08-11 15:10:19',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Plantowa',
#    'number': '',
#    'geo': 'Teofilów, Bałuty, Łódź, łódzkie'},
#   {'id': 59893373,
#    'title': 'Mieszkanie do wynajęcia 2 pokoje ul. Lutomierska',
#    'slug': 'mieszkanie-do-wynajecia-2-pokoje-ul-lutomierska-ID43j09',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2000,
#    'rentPrice': 500,
#    'areaInSquareMeters': 34,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 14:38:27',
#    'dateCreatedFirst': '2019-10-31 12:38:08',
#    'pushedUpAt': '2023-08-11T14:38:27+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Lutomierska',
#    'number': '',
#    'geo': 'Żubardź, Bałuty, Łódź, łódzkie'},
#   {'id': 64506870,
#    'title': '‼️Klimatyczna kawalerka / miejsce postojowe‼️',
#    'slug': 'klimatyczna-kawalerka-miejsce-postojowe-ID4mFbo',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Home Expert',
#    'totalPrice': 1400,
#    'rentPrice': 400,
#    'areaInSquareMeters': 17,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 14:35:04',
#    'dateCreatedFirst': '2023-08-11 14:34:57',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Poznańska',
#    'number': '',
#    'geo': 'Górniak, Górna, Łódź, łódzkie'},
#   {'id': 64506862,
#    'title': 'mieszkanie do wynajęcia dla studenta',
#    'slug': 'mieszkanie-do-wynajecia-dla-studenta-ID4mFbg',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Mediatore Nieruchomości',
#    'totalPrice': 1600,
#    'rentPrice': 400,
#    'areaInSquareMeters': 22,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 14:32:42',
#    'dateCreatedFirst': '2023-08-11 14:32:36',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Politechniczna, Polesie, Łódź, łódzkie'},
#   {'id': 64506861,
#    'title': 'Łódź Górna wynajmę M-3',
#    'slug': 'lodz-gorna-wynajme-m-3-ID4mFbf',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Mediatore Nieruchomości',
#    'totalPrice': 1800,
#    'rentPrice': 400,
#    'areaInSquareMeters': 37,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 14:32:40',
#    'dateCreatedFirst': '2023-08-11 14:32:35',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'},
#   {'id': 64472809,
#    'title': 'Śródmieście. Dwa pokoje w atrakcyjnej kamienicy.',
#    'slug': 'srodmiescie-dwa-pokoje-w-atrakcyjnej-kamienicy-ID4mvk1',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Real Nieruchomości',
#    'totalPrice': 2200,
#    'rentPrice': 1000,
#    'areaInSquareMeters': 60,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 14:18:55',
#    'dateCreatedFirst': '2023-08-01 15:29:01',
#    'pushedUpAt': '2023-08-11T14:18:55+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'},
#   {'id': 64461805,
#    'title': 'OKAZJA KAWALERKA w ŚWIETNEJ LOKALIZACJI ŁODZI!!!',
#    'slug': 'okazja-kawalerka-w-swietnej-lokalizacji-lodzi-ID4mtsx',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1000,
#    'rentPrice': 995,
#    'areaInSquareMeters': 28,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 14:12:42',
#    'dateCreatedFirst': '2023-07-28 12:40:02',
#    'pushedUpAt': '2023-08-11T14:12:42+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Walerego Wróblewskiego',
#    'number': '21',
#    'geo': 'Politechniczna, Polesie, Łódź, łódzkie'},
#   {'id': 64506763,
#    'title': 'Retkinia-przestronne 2-pokojowe po remoncie',
#    'slug': 'retkinia-przestronne-2-pokojowe-po-remoncie-ID4mF9F',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'ARLI Nieruchomości',
#    'totalPrice': 1650,
#    'rentPrice': 740,
#    'areaInSquareMeters': 54.23,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 14:12:07',
#    'dateCreatedFirst': '2023-08-11 14:11:51',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Batalionów Chłopskich',
#    'number': '',
#    'geo': 'Retkinia, Polesie, Łódź, łódzkie'},
#   {'id': 64443169,
#    'title': 'Przytulna kawalerka na ul. Żwirki',
#    'slug': 'przytulna-kawalerka-na-ul-zwirki-ID4moBX',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1800,
#    'rentPrice': 480,
#    'areaInSquareMeters': 28,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 14:04:53',
#    'dateCreatedFirst': '2023-07-22 14:02:04',
#    'pushedUpAt': '2023-08-11T14:04:53+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. kpt. Pilota Franciszka Żwirki',
#    'number': '21',
#    'geo': 'Politechniczna, Polesie, Łódź, łódzkie'},
#   {'id': 60042590,
#    'title': 'NOWE PRZYTULNE MIESZKANIE 2 pokoje - retkinia 38m2',
#    'slug': 'nowe-przytulne-mieszkanie-2-pokoje-retkinia-38m2-ID43WOS',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2100,
#    'rentPrice': 500,
#    'areaInSquareMeters': 38,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 14:01:14',
#    'dateCreatedFirst': '2019-12-16 11:03:14',
#    'pushedUpAt': '2023-08-11T14:01:15+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Karolew, Polesie, Łódź, łódzkie'},
#   {'id': 64428539,
#    'title': '2-pok, 94m2 okolice Kampusu UŁ - I speak English',
#    'slug': '2-pok-94m2-okolice-kampusu-ul-i-speak-english-ID4mkNZ',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 3000,
#    'rentPrice': 850,
#    'areaInSquareMeters': 94,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 13:59:41',
#    'dateCreatedFirst': '2023-07-18 13:28:19',
#    'pushedUpAt': '2023-08-11T13:59:41+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Radiostacja, Śródmieście, Łódź, łódzkie'},
#   {'id': 64506392,
#    'title': 'Łódź - Widzew | kawalerka | dobra lokalizacja',
#    'slug': 'lodz-widzew-kawalerka-dobra-lokalizacja-ID4mF3G',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Flat4Rent',
#    'totalPrice': 1200,
#    'rentPrice': 500,
#    'areaInSquareMeters': 21,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 13:13:30',
#    'dateCreatedFirst': '2023-08-11 13:13:25',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Targowa',
#    'number': '',
#    'geo': 'Księży Młyn, Widzew, Łódź, łódzkie'},
#   {'id': 64506086,
#    'title': 'Wynajmę 3 pokojowe mieszkanie,',
#    'slug': 'wynajme-3-pokojowe-mieszkanie-ID4mEYK',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2200,
#    'rentPrice': 575,
#    'areaInSquareMeters': 52,
#    'roomsNumber': 'THREE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 12:31:43',
#    'dateCreatedFirst': '2023-08-11 12:21:44',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Władysława Broniewskiego',
#    'number': '',
#    'geo': 'Dąbrowa, Górna, Łódź, łódzkie'},
#   {'id': 62057082,
#    'title': 'Mieszkanie 2 pokojowe 38m2,Rojna',
#    'slug': 'mieszkanie-2-pokojowe-38m2-rojna-ID4cnSG',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1600,
#    'rentPrice': 450,
#    'areaInSquareMeters': 38,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 12:31:28',
#    'dateCreatedFirst': '2021-07-11 14:49:17',
#    'pushedUpAt': '2023-08-11T12:31:28+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Rojna',
#    'number': '',
#    'geo': 'Teofilów, Bałuty, Łódź, łódzkie'},
#   {'id': 64334784,
#    'title': 'Mieszkanie, 44,32 m², Łódź',
#    'slug': 'mieszkanie-44-32-m-lodz-ID4lVpO',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'EXPERT s.c. Z.Kubiński M.Strzelecka',
#    'totalPrice': 2200,
#    'rentPrice': 600,
#    'areaInSquareMeters': 44.32,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 12:13:15',
#    'dateCreatedFirst': '2023-06-19 13:05:04',
#    'pushedUpAt': '2023-08-11T12:13:16+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'},
#   {'id': 64505900,
#    'title': 'Mieszkanie 2-pokojowe na wynajem, ul. Astronautów',
#    'slug': 'mieszkanie-2-pokojowe-na-wynajem-ul-astronautow-ID4mEWK',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Rent&Service Paulina Widymajer',
#    'totalPrice': 1500,
#    'rentPrice': 445,
#    'areaInSquareMeters': 31.96,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 11:51:06',
#    'dateCreatedFirst': '2023-08-11 11:51:01',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Astronautów',
#    'number': '',
#    'geo': 'Kurak, Górna, Łódź, łódzkie'},
#   {'id': 64505739,
#    'title': 'Przytulna kawalerka w ścisłym CENTRUM Próchnika 9',
#    'slug': 'przytulna-kawalerka-w-scislym-centrum-prochnika-9-ID4mET9',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1350,
#    'rentPrice': 270,
#    'areaInSquareMeters': 22,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 11:34:52',
#    'dateCreatedFirst': '2023-08-11 11:32:53',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Adama Próchnika',
#    'number': '9',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'},
#   {'id': 64505656,
#    'title': 'Klimatyzowany apartament z widokiem na Manufakurę',
#    'slug': 'klimatyzowany-apartament-z-widokiem-na-manufakure-ID4mERO',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'MK Property Brokers',
#    'totalPrice': 3000,
#    'rentPrice': 790,
#    'areaInSquareMeters': 59,
#    'roomsNumber': 'THREE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 11:16:42',
#    'dateCreatedFirst': '2023-08-11 11:16:31',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Stare Miasto, Bałuty, Łódź, łódzkie'},
#   {'id': 64345565,
#    'title': 'Kawalerka - Wynajem',
#    'slug': 'kawalerka-wynajem-ID4lZdH',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Landers Nieruchomości',
#    'totalPrice': 1800,
#    'rentPrice': '',
#    'areaInSquareMeters': 30,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 11:05:40',
#    'dateCreatedFirst': '2023-06-22 10:49:42',
#    'pushedUpAt': '2023-08-11T11:05:41+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Stare Polesie, Polesie, Łódź, łódzkie'},
#   {'id': 47965092,
#    'title': 'Mieszkanie dla studenta',
#    'slug': 'mieszkanie-dla-studenta-ID3ffUv',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1700,
#    'rentPrice': 390,
#    'areaInSquareMeters': 33,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 11:02:34',
#    'dateCreatedFirst': '2017-04-19 17:26:41',
#    'pushedUpAt': '2017-07-14T20:01:41+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Gdańska',
#    'number': '',
#    'geo': 'Stare Polesie, Polesie, Łódź, łódzkie'},
#   {'id': 62117083,
#    'title': 'Mieszkanie dla studenta',
#    'slug': 'mieszkanie-dla-studenta-ID4cDur',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1950,
#    'rentPrice': 450,
#    'areaInSquareMeters': 36.22,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 10:57:37',
#    'dateCreatedFirst': '2021-07-28 15:52:58',
#    'pushedUpAt': '2022-09-04T08:37:18+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Stare Polesie, Polesie, Łódź, łódzkie'},
#   {'id': 62038571,
#    'title': 'Bezpośrednio Wierzbowa 12 60 m2 Garaż gratis',
#    'slug': 'bezposrednio-wierzbowa-12-60-m2-garaz-gratis-ID4cj47',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2300,
#    'rentPrice': 720,
#    'areaInSquareMeters': 60,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 10:57:22',
#    'dateCreatedFirst': '2021-07-06 12:30:41',
#    'pushedUpAt': '2023-08-11T10:57:23+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'},
#   {'id': 60876736,
#    'title': 'Mieszkanie dla studenta',
#    'slug': 'mieszkanie-dla-studenta-ID47qOQ',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1700,
#    'rentPrice': 390,
#    'areaInSquareMeters': 27,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 10:49:51',
#    'dateCreatedFirst': '2020-08-28 11:20:51',
#    'pushedUpAt': '2020-10-17T14:34:03+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Jana Matejki',
#    'number': '',
#    'geo': 'Radiostacja, Śródmieście, Łódź, łódzkie'},
#   {'id': 64262287,
#    'title': 'Mieszkanie 2 - pokojowe + garderoba RETKINIA',
#    'slug': 'mieszkanie-2-pokojowe-garderoba-retkinia-ID4lDyw',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2350,
#    'rentPrice': 650,
#    'areaInSquareMeters': 43,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 10:38:11',
#    'dateCreatedFirst': '2023-05-25 22:44:37',
#    'pushedUpAt': '2023-08-11T10:38:11+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'al. ks. kard. Stefana Wyszyńskiego',
#    'number': '',
#    'geo': 'Retkinia, Polesie, Łódź, łódzkie'},
#   {'id': 64486071,
#    'title': 'Wynajmę 2 pokoje w mieszkaniu na Wróblewskiego',
#    'slug': 'wynajme-2-pokoje-w-mieszkaniu-na-wroblewskiego-ID4mzLW',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1050,
#    'rentPrice': 350,
#    'areaInSquareMeters': 41.5,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 09:43:46',
#    'dateCreatedFirst': '2023-08-05 00:23:24',
#    'pushedUpAt': '2023-08-11T09:43:46+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Walerego Wróblewskiego',
#    'number': '21',
#    'geo': 'Nowe Rokicie, Górna, Łódź, łódzkie'},
#   {'id': 64445784,
#    'title': 'Mieszkanie 26m2 blisko Manufaktury nowy blok',
#    'slug': 'mieszkanie-26m2-blisko-manufaktury-nowy-blok-ID4mpi8',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1900,
#    'rentPrice': 400,
#    'areaInSquareMeters': 26,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 09:27:18',
#    'dateCreatedFirst': '2023-07-24 09:24:08',
#    'pushedUpAt': '2023-08-11T09:27:18+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Wojska Polskiego',
#    'number': '',
#    'geo': 'Marysin Doły, Bałuty, Łódź, łódzkie'},
#   {'id': 64442740,
#    'title': 'Kawalerka z miejscem parkingowym w centrum',
#    'slug': 'kawalerka-z-miejscem-parkingowym-w-centrum-ID4mow2',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1490,
#    'rentPrice': 350,
#    'areaInSquareMeters': 20,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 09:26:38',
#    'dateCreatedFirst': '2023-07-22 09:24:59',
#    'pushedUpAt': '2023-08-11T09:26:38+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Rewolucji 1905 r.',
#    'number': '',
#    'geo': 'Fabryczna, Śródmieście, Łódź, łódzkie'},
#   {'id': 62990777,
#    'title': 'Wynajmę mieszkanie/ Łódź CENTRUM/ Apartm. for rent',
#    'slug': 'wynajme-mieszkanie-lodz-centrum-apartm-for-rent-ID4giMh',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2250,
#    'rentPrice': 390,
#    'areaInSquareMeters': 34.38,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 08:57:59',
#    'dateCreatedFirst': '2022-04-15 15:29:32',
#    'pushedUpAt': '2023-08-11T08:57:59+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. kpt. Pilota Franciszka Żwirki',
#    'number': '',
#    'geo': 'Politechniczna, Polesie, Łódź, łódzkie'},
#   {'id': 64470482,
#    'title': 'Wynajmę mieszkanie 2-pokoje. na wrześnieńskiej 42',
#    'slug': 'wynajme-mieszkanie-2-pokoje-na-wrzesnienskiej-42-ID4mwIu',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1400,
#    'rentPrice': 550,
#    'areaInSquareMeters': 31,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 08:32:45',
#    'dateCreatedFirst': '2023-08-01 08:30:39',
#    'pushedUpAt': '2023-08-11T08:32:46+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Wrześnieńska',
#    'number': '',
#    'geo': 'Stare Bałuty, Bałuty, Łódź, łódzkie'},
#   {'id': 63989629,
#    'title': 'Przestronna kawalerka ManuPark',
#    'slug': 'przestronna-kawalerka-manupark-ID4kuCN',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1700,
#    'rentPrice': 300,
#    'areaInSquareMeters': 30,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 07:38:02',
#    'dateCreatedFirst': '2023-03-01 08:46:12',
#    'pushedUpAt': '2023-08-11T07:38:02+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Ogrodowa',
#    'number': '',
#    'geo': 'Stare Polesie, Polesie, Łódź, łódzkie'},
#   {'id': 64445480,
#    'title': 'Nieaktualne !!! M3 - opłaty w cenie , p',
#    'slug': 'nieaktualne-m3-oplaty-w-cenie-p-ID4mpde',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2600,
#    'rentPrice': '',
#    'areaInSquareMeters': 37,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 00:43:19',
#    'dateCreatedFirst': '2023-07-24 00:40:47',
#    'pushedUpAt': '2023-08-11T00:43:19+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Złotno, Polesie, Łódź, łódzkie'},
#   {'id': 63245592,
#    'title': 'Wynajmę apartament, wysoki standard, garaż',
#    'slug': 'wynajme-apartament-wysoki-standard-garaz-ID4hn4c',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 3200,
#    'rentPrice': 845,
#    'areaInSquareMeters': 74,
#    'roomsNumber': 'THREE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 00:16:18',
#    'dateCreatedFirst': '2022-06-29 12:45:57',
#    'pushedUpAt': '2023-08-11T00:16:18+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. ks. bp. Wincentego Tymienieckiego',
#    'number': '25d',
#    'geo': 'Stare Polesie, Polesie, Łódź, łódzkie'},
#   {'id': 64504936,
#    'title': 'Mieszkanie, 37,88 m², Łódź',
#    'slug': 'mieszkanie-37-88-m-lodz-ID4mEGc',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'PROPERTY Agencja Nieruchomości Dębski Andrzej',
#    'totalPrice': 1400,
#    'rentPrice': 500,
#    'areaInSquareMeters': 37.88,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 00:15:31',
#    'dateCreatedFirst': '2023-08-11 00:15:22',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Teofilów, Bałuty, Łódź, łódzkie'},
#   {'id': 63465182,
#    'title': 'Mieszkanie Łódź Widzew, Strzemińskiego',
#    'slug': 'mieszkanie-lodz-widzew-strzeminskiego-ID4iibY',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2000,
#    'rentPrice': 700,
#    'areaInSquareMeters': 47,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 00:13:30',
#    'dateCreatedFirst': '2022-09-04 20:12:12',
#    'pushedUpAt': '2023-08-11T00:13:31+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Władysława Strzemińskiego',
#    'number': '',
#    'geo': 'Zarzew, Widzew, Łódź, łódzkie'},
#   {'id': 64504913,
#    'title': 'Przestronne 2-pok. (50m2) po remoncie 1. najem; PŁ',
#    'slug': 'przestronne-2-pok-50m2-po-remoncie-1-najem-pl-ID4mEFP',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2000,
#    'rentPrice': 450,
#    'areaInSquareMeters': 50,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-11 00:03:29',
#    'dateCreatedFirst': '2023-08-11 00:00:11',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Stefana Rogozińskiego',
#    'number': '',
#    'geo': 'Nowe Rokicie, Górna, Łódź, łódzkie'},
#   {'id': 64485929,
#    'title': 'Dwa pokoje świeżo po remoncie',
#    'slug': 'dwa-pokoje-swiezo-po-remoncie-ID4mzJD',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2200,
#    'rentPrice': 514,
#    'areaInSquareMeters': 35,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 22:21:31',
#    'dateCreatedFirst': '2023-08-04 22:17:58',
#    'pushedUpAt': '2023-08-10T22:21:32+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Bydgoska',
#    'number': '',
#    'geo': 'Żubardź, Bałuty, Łódź, łódzkie'},
#   {'id': 64445324,
#    'title': 'Wyjątkowa kawalerka z werandą na Radiostacji!',
#    'slug': 'wyjatkowa-kawalerka-z-weranda-na-radiostacji-ID4mpaI',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1600,
#    'rentPrice': 350,
#    'areaInSquareMeters': 23,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 22:20:22',
#    'dateCreatedFirst': '2023-07-23 22:18:07',
#    'pushedUpAt': '2023-08-10T22:20:22+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. dr. Stefana Kopcińskiego',
#    'number': '',
#    'geo': 'Radiostacja, Śródmieście, Łódź, łódzkie'},
#   {'id': 62645616,
#    'title': 'nowy apartament, centrum, bezpośrednio',
#    'slug': 'nowy-apartament-centrum-bezposrednio-ID4eQZa',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1900,
#    'rentPrice': 600,
#    'areaInSquareMeters': 32,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 22:16:28',
#    'dateCreatedFirst': '2022-01-10 20:07:46',
#    'pushedUpAt': '2023-08-10T22:16:28+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Stare Polesie, Polesie, Łódź, łódzkie'},
#   {'id': 64445301,
#    'title': 'Piękna kawalerka na Radiostacji!',
#    'slug': 'piekna-kawalerka-na-radiostacji-ID4mpal',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1600,
#    'rentPrice': 350,
#    'areaInSquareMeters': 24,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 22:06:11',
#    'dateCreatedFirst': '2023-07-23 22:01:27',
#    'pushedUpAt': '2023-08-10T22:06:11+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Radiostacja, Śródmieście, Łódź, łódzkie'},
#   {'id': 63642685,
#    'title': 'dwupokojowe 40 m2,',
#    'slug': 'dwupokojowe-40-m2-ID4j2mW',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': '',
#    'totalPrice': 1800,
#    'rentPrice': 500,
#    'areaInSquareMeters': 40,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 21:39:59',
#    'dateCreatedFirst': '2022-10-27 13:10:40',
#    'pushedUpAt': '2023-08-10T21:39:59+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Emilii Plater',
#    'number': '',
#    'geo': 'Marysin Doły, Bałuty, Łódź, łódzkie'},
#   {'id': 64504587,
#    'title': 'Wynajmę mieszkanie 76m*, Radogoszcz, ul. Okoniowa',
#    'slug': 'wynajme-mieszkanie-76m-radogoszcz-ul-okoniowa-ID4mEAz',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2200,
#    'rentPrice': 900,
#    'areaInSquareMeters': 76,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 20:54:15',
#    'dateCreatedFirst': '2023-08-10 20:51:43',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Okoniowa',
#    'number': '',
#    'geo': 'Radogoszcz, Bałuty, Łódź, łódzkie'},
#   {'id': 64469786,
#    'title': 'mieszkanie do wynajęcia-rezerwacja do 21.08.2023',
#    'slug': 'mieszkanie-do-wynajecia-rezerwacja-do-21-08-2023-ID4mwxg',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2500,
#    'rentPrice': 800,
#    'areaInSquareMeters': 62,
#    'roomsNumber': 'THREE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 20:45:14',
#    'dateCreatedFirst': '2023-07-31 20:41:37',
#    'pushedUpAt': '2023-08-10T20:45:14+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Lutomierska',
#    'number': '',
#    'geo': 'Żubardź, Bałuty, Łódź, łódzkie'},
#   {'id': 64504512,
#    'title': 'Wygodne mieszkanie w Centrum, 2-pokojowe, 52m2.',
#    'slug': 'wygodne-mieszkanie-w-centrum-2-pokojowe-52m2-ID4mEzm',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2000,
#    'rentPrice': 700,
#    'areaInSquareMeters': 52,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 20:14:32',
#    'dateCreatedFirst': '2023-08-10 20:06:32',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'},
#   {'id': 64465042,
#    'title': 'Nowoczesne przy Manufakturze - Duży ogród, nowe',
#    'slug': 'nowoczesne-przy-manufakturze-duzy-ogrod-nowe-ID4muiK',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 3900,
#    'rentPrice': 800,
#    'areaInSquareMeters': 70,
#    'roomsNumber': 'THREE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 20:03:41',
#    'dateCreatedFirst': '2023-07-29 20:01:12',
#    'pushedUpAt': '2023-08-10T20:03:41+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Lutomierska',
#    'number': '',
#    'geo': 'Stare Miasto, Bałuty, Łódź, łódzkie'},
#   {'id': 64504476,
#    'title': 'Przytulne mieszkanie na Bałutach',
#    'slug': 'przytulne-mieszkanie-na-balutach-ID4mEyM',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1500,
#    'rentPrice': 550,
#    'areaInSquareMeters': 36,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 19:53:15',
#    'dateCreatedFirst': '2023-08-10 19:45:44',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Wawelska',
#    'number': '',
#    'geo': 'Stare Bałuty, Bałuty, Łódź, łódzkie'},
#   {'id': 62095965,
#    'title': 'Piękne mieszkanie Nowy Janów, 49m2, garaż, komórka',
#    'slug': 'piekne-mieszkanie-nowy-janow-49m2-garaz-komorka-ID4cxZP',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2500,
#    'rentPrice': 400,
#    'areaInSquareMeters': 49,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 19:21:47',
#    'dateCreatedFirst': '2021-07-22 12:23:30',
#    'pushedUpAt': '2023-05-27T22:39:16+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'Nowy Janów',
#    'number': '',
#    'geo': 'Olechów, Widzew, Łódź, łódzkie'},
#   {'id': 64504383,
#    'title': 'Nowoczesny apartament bardzo blisko centrum Łodzi',
#    'slug': 'nowoczesny-apartament-bardzo-blisko-centrum-lodzi-ID4mExh',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Plena Invest',
#    'totalPrice': 3500,
#    'rentPrice': 700,
#    'areaInSquareMeters': 68.7,
#    'roomsNumber': 'THREE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 19:09:00',
#    'dateCreatedFirst': '2023-08-10 19:08:51',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Zdrowie, Polesie, Łódź, łódzkie'},
#   {'id': 64469510,
#    'title': 'Mikrokawalerka 5 min od deptaka/UMED i UŁ 12 min',
#    'slug': 'mikrokawalerka-5-min-od-deptaka-umed-i-ul-12-min-ID4mwsO',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': '',
#    'totalPrice': 1500,
#    'rentPrice': 160,
#    'areaInSquareMeters': 16.5,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 18:54:24',
#    'dateCreatedFirst': '2023-07-31 18:50:55',
#    'pushedUpAt': '2023-08-10T18:54:24+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Rewolucji 1905 r.',
#    'number': '',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'},
#   {'id': 64504300,
#    'title': 'Urocza kawalerka z antresolą',
#    'slug': 'urocza-kawalerka-z-antresola-ID4mEwV',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1900,
#    'rentPrice': 300,
#    'areaInSquareMeters': 26,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 18:40:14',
#    'dateCreatedFirst': '2023-08-10 18:38:28',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Jana Kilińskiego',
#    'number': '',
#    'geo': 'Księży Młyn, Widzew, Łódź, łódzkie'},
#   {'id': 64441894,
#    'title': 'studio 18 m2 ul. Piotrkowska 37 (min 1 miesiąc)',
#    'slug': 'studio-18-m2-ul-piotrkowska-37-min-1-miesiac-ID4moho',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1600,
#    'rentPrice': 300,
#    'areaInSquareMeters': 18,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 18:14:25',
#    'dateCreatedFirst': '2023-07-21 18:11:09',
#    'pushedUpAt': '2023-08-10T18:14:25+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': '',
#    'number': '',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'},
#   {'id': 64469392,
#    'title': 'Mieszkanie na Retkini - os. Piaski',
#    'slug': 'mieszkanie-na-retkini-os-piaski-ID4mwqU',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1900,
#    'rentPrice': 500,
#    'areaInSquareMeters': 42,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 18:03:25',
#    'dateCreatedFirst': '2023-07-31 18:02:09',
#    'pushedUpAt': '2023-08-10T18:03:25+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Piaski',
#    'number': '',
#    'geo': 'Retkinia, Polesie, Łódź, łódzkie'},
#   {'id': 64377124,
#    'title': 'M4 - 3 pokoje - 55m2 - ul. Piękna 42',
#    'slug': 'm4-3-pokoje-55m2-ul-piekna-42-ID4m7qI',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2450,
#    'rentPrice': 750,
#    'areaInSquareMeters': 55,
#    'roomsNumber': 'THREE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 17:49:51',
#    'dateCreatedFirst': '2023-07-01 17:43:39',
#    'pushedUpAt': '2023-08-10T17:49:51+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Piękna',
#    'number': '',
#    'geo': 'Nowe Rokicie, Górna, Łódź, łódzkie'},
#   {'id': 64441797,
#    'title': 'Stocka Górna Górniak Stare Górki 0% prowizji',
#    'slug': 'stocka-gorna-gorniak-stare-gorki-0-prowizji-ID4mofP',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 1100,
#    'rentPrice': 550,
#    'areaInSquareMeters': 21.48,
#    'roomsNumber': 'ONE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 17:24:40',
#    'dateCreatedFirst': '2023-07-21 17:23:21',
#    'pushedUpAt': '2023-08-10T17:24:40+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Stocka',
#    'number': '',
#    'geo': 'Górniak, Górna, Łódź, łódzkie'},
#   {'id': 64032628,
#    'title': 'Wynajmę mieszkanie w apartamentowcu na Łąkowej',
#    'slug': 'wynajme-mieszkanie-w-apartamentowcu-na-lakowej-ID4kFOk',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2250,
#    'rentPrice': 700,
#    'areaInSquareMeters': 53,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 17:16:21',
#    'dateCreatedFirst': '2023-03-13 19:59:35',
#    'pushedUpAt': '2023-08-10T17:16:21+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Łąkowa',
#    'number': '',
#    'geo': 'Stare Polesie, Polesie, Łódź, łódzkie'},
#   {'id': 64504026,
#    'title': 'nowe – Tuwima 64/106 - bez pośredników',
#    'slug': 'nowe-tuwima-64-106-bez-posrednikow-ID4mErv',
#    'estate': 'FLAT',
#    'developmentId': 63786368,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'Vantage Rent',
#    'totalPrice': 2707,
#    'rentPrice': 490,
#    'areaInSquareMeters': 57.61,
#    'roomsNumber': 'THREE',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 17:08:54',
#    'dateCreatedFirst': '2023-08-10 17:08:47',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Juliana Tuwima',
#    'number': '',
#    'geo': 'Fabryczna Widzew, Widzew, Łódź, łódzkie'},
#   {'id': 64458695,
#    'title': 'Ładne mieszkanie w centrum, Targowa',
#    'slug': 'ladne-mieszkanie-w-centrum-targowa-ID4msEn',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'BROKERmania Joanna Zaremba',
#    'totalPrice': 2300,
#    'rentPrice': 400,
#    'areaInSquareMeters': 34.44,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 17:01:08',
#    'dateCreatedFirst': '2023-07-27 14:05:30',
#    'pushedUpAt': '2023-08-10T17:01:08+02:00',
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Targowa',
#    'number': '',
#    'geo': 'Księży Młyn, Widzew, Łódź, łódzkie'},
#   {'id': 64503984,
#    'title': 'Wynajmę dwupokojowe mieszkanie 42m2',
#    'slug': 'wynajme-dwupokojowe-mieszkanie-42m2-ID4mEqQ',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2000,
#    'rentPrice': 605.68,
#    'areaInSquareMeters': 42,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 16:56:44',
#    'dateCreatedFirst': '2023-08-10 16:55:18',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Rybna',
#    'number': '',
#    'geo': 'Stare Miasto, Bałuty, Łódź, łódzkie'},
#   {'id': 64503889,
#    'title': 'Apartament w samym centrum Łodzi,Tylna, Garaż podz',
#    'slug': 'apartament-w-samym-centrum-lodzi-tylna-garaz-podz-ID4mEpj',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': True,
#    'agency': '',
#    'totalPrice': 2950,
#    'rentPrice': 700,
#    'areaInSquareMeters': 55,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 16:28:48',
#    'dateCreatedFirst': '2023-08-10 16:27:14',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Tylna',
#    'number': '',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'},
#   {'id': 64503854,
#    'title': 'Apartament 54 m2 w lofcie na wynajem',
#    'slug': 'apartament-54-m2-w-lofcie-na-wynajem-ID4mEoK',
#    'estate': 'FLAT',
#    'developmentId': 0,
#    'transaction': 'RENT',
#    'isPrivateOwner': False,
#    'agency': 'RE/MAX Polska - Międzynarodowa Sieć Biur Nieruchomości',
#    'totalPrice': 2850,
#    'rentPrice': '',
#    'areaInSquareMeters': 54.13,
#    'roomsNumber': 'TWO',
#    'peoplePerRoom': None,
#    'dateCreated': '2023-08-10 16:20:31',
#    'dateCreatedFirst': '2023-08-10 16:20:19',
#    'pushedUpAt': None,
#    'latitude': '',
#    'longitude': '',
#    'cityname': 'Łódź',
#    'districtname': '',
#    'streetname': 'ul. Tylna',
#    'number': '',
#    'geo': 'Centrum, Śródmieście, Łódź, łódzkie'}]}

# %%
extract_ads_from_json(jsondata)['data_list'][8].keys()
# Out:
# dict_keys(['id', 'title', 'slug', 'estate', 'developmentId', 'transaction', 'isPrivateOwner', 'agency', 'totalPrice', 'rentPrice', 'areaInSquareMeters', 'roomsNumber', 'peoplePerRoom', 'dateCreated', 'dateCreatedFirst', 'pushedUpAt', 'latitude', 'longitude', 'cityname', 'districtname', 'streetname', 'number', 'geo'])
